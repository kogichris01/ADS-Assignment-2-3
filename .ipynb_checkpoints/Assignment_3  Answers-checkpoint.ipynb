# %% [markdown]
# # Importing the necessary tools and getting a general idea of the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load in the data to a dataframe
attr = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
attr.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# QUESTION ONE (1)

# %%
# Grouping the data by Job Role and Attrition Status, and calculate the mean Distance From Home
mean_distance = attr.groupby(['JobRole', 'Attrition'])['DistanceFromHome'].mean().reset_index(name= "DistanceFromHome")
mean_distance.head(20)
# Out:
#                       JobRole Attrition  DistanceFromHome
# 0   Healthcare Representative        No          9.204918
# 1   Healthcare Representative       Yes         17.666667
# 2             Human Resources        No          6.600000
# 3             Human Resources       Yes         13.416667
# 4       Laboratory Technician        No          9.329949
# 5       Laboratory Technician       Yes          9.661290
# 6                     Manager        No          7.927835
# 7                     Manager       Yes         10.000000
# 8      Manufacturing Director        No          9.533333
# 9      Manufacturing Director       Yes          8.800000
# 10          Research Director        No          8.474359
# 11          Research Director       Yes          7.000000
# 12         Research Scientist        No          8.869388
# 13         Research Scientist       Yes          9.765957
# 14            Sales Executive        No          9.026022
# ...

# %%
plt.figure(figsize=(20,8))
sns.set_style('darkgrid')
sns.barplot(x='JobRole', y='DistanceFromHome', hue='Attrition', data=mean_distance)
plt.title('Distance from Home by Job Role and Attrition')
plt.grid()
plt.show()

# %% [markdown]
# QUESTION  TWO(2)

# %%
# Grouping the data by Job Role and Attrition Status, and calculate the mean Distance From Home
mean_monthly_income = attr.groupby(['Education', 'Attrition'])['MonthlyIncome'].mean().reset_index(name= "MonthlyIncome")
mean_monthly_income.head(20)
# Out:
#    Education Attrition  MonthlyIncome
# 0          1        No    5926.129496
# 1          1       Yes    4360.161290
# 2          2        No    6586.058824
# 3          2       Yes    4282.545455
# 4          3        No    6882.919662
# 5          3       Yes    4770.242424
# 6          4        No    7087.814706
# 7          4       Yes    5335.155172
# 8          5        No    8559.906977
# 9          5       Yes    5850.200000

# %%
plt.figure(figsize=(20, 9))
sns.set_style('darkgrid')
sns.barplot(x='Education', y='MonthlyIncome', hue='Attrition', data= mean_monthly_income)
plt.title('Monthly Income by Education and Attrition')
sns.set_style('ticks')
plt.grid()
plt.show()
